# %% [markdown]
# # Installation

# %%
#!pip install -q openai
#!pip install -q gradio

# %% [markdown]
# # Imports

# %%
import openai
import gradio as gr

# %% [markdown]
# # API Key
#
# openai.api_key = Replace this with your API key: https://beta.openai.com/docs/quickstart/add-your-api-key

# %%
openai.api_key = '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'

# %% [markdown]
# # OpenAI Chat

# %%
def openai_chat(prompt):
    completions = openai.Completion.create(
        engine="text-davinci-003",
        prompt=prompt,
        max_tokens=1024,
        n=1,
        temperature=0.5,
    )

    message = completions.choices[0].text
    return message.strip()

# %% [markdown]
# # Gradio Interface Function

# %%
def chatbot(input, history=[]):
    output = openai_chat(input)
    history.append((input, output))
    return history, history

# %% [markdown]
# # Launch Interface

# %%
gr.Interface(fn = chatbot,
             inputs = ["text",'state'],
             outputs = ["chatbot",'state']).launch(debug = True)
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Keyboard interruption in main thread... closing server.

# %%
# write a general multi-line prompt

prompt = """
Generate a latex table summarizing the treatment plan based on the following text:

Mrs. X Is a 64-year-old woman diagnosed with a T1c N0 M0 invasive ductal carcinoma of the right breast status post lumpectomy with sentinel lymph node biopsy with 0/1 lymph nodes involved with metastatic disease, the specimen was ER / PR positive, HER2 Neu negative with a low Oncotype score so no adjuvant chemotherapy was given. I would anticipate treating the right breast to a total dose of 4256 cGy over the course of 16 fractions followed by a boost to the lumpectomy site to a total dose of 1000 cGy over the course of 4 fractions utilizing 6 mV photons and a tangent orientation.

The columns should include the treatment region, either whole breast or boost, total dose, number of fractions, dose per fraction, modality and technique
"""

# %%
print(prompt)
# Out:
# Generate a latex table summarizing the treatment plan based on the following text:
#
# Mrs. X Is a 64-year-old woman diagnosed with a T1c N0 M0 invasive ductal carcinoma of the right breast status post lumpectomy with sentinel lymph node biopsy with 0/1 lymph nodes involved with metastatic disease, the specimen was ER / PR positive, HER2 Neu negative with a low Oncotype score so no adjuvant chemotherapy was given. I would anticipate treating the right breast to a total dose of 4256 cGy over the course of 16 fractions followed by a boost to the lumpectomy site to a total dose of 1000 cGy over the course of 4 fractions utilizing 6 mV photons and a tangent orientation.
#
# The columns should include the treatment region, either whole breast or boost, total dose, number of fractions, dose per fraction, modality and technique

# %%
print(openai_chat(prompt))
# Out:
# \begin{tabular}{|l|l|l|l|l|l|}
# \hline
# \textbf{Treatment Region} & \textbf{Total Dose (cGy)} & \textbf{Number of Fractions} & \textbf{Dose per Fraction (cGy)} & \textbf{Modality} & \textbf{Technique} \\ \hline
# Whole Breast & 4256 & 16 & 266 & 6 mV Photons & Tangent \\ \hline
# Boost & 1000 & 4 & 250 & 6 mV Photons & Tangent \\ \hline
# \end{tabular}
